# %% [markdown]
# # Optics Laboratory Simulation
#
#
# 1) An optical system consists of two thick lenses (medium around is air), the first lens has refractive index $n_1 = 1.50$, thickness: $t_1 = 5mm$ surface radii
#
# $$
# R_1 = + 40mm
# $$
# $$
# R_2 = - 40mm
# $$
#
# And lens 2 is a discance $d_{12} = 30mm$ (distance vertex to vertex), refractive index: $n_2 = 1.6$, thickness: $t_2 = 4mm$, surface radii
#
# $$
#     R_3 = +25mm
# $$
# $$
#     R_4 = -35mm
# $$

# %% [markdown]
# ## Computing values
#
# For calculating the focal points, we find the following:
#
# $$
# \frac{1}{f} = (n_l - 1 ) \left( \frac{1}{R_1} - \frac{1}{R_2} + \frac{(n_l - 1)t}{n_l R_1 R_2} \right)
# $$
# $$
# \implies f_1 = \boxed{+40.85mm}
# $$
# $$
# \implies f_2 = \boxed{+24.93mm}
# $$
#
# For calculating the principle planes we use the following formula:
#
# $$
# h_n = - \frac{f(n - 1)t}{n R_n}
# $$
#
# $$
# \implies h_{11} = \boxed{-1.702mm}
# $$
#
# $$
# \implies h_{12} = \boxed{1.702mm}
# $$
#
# $$
# \implies h_{21} = \boxed{-1.496mm}
# $$
#
# $$
# \implies h_{22} = \boxed{1.068mm}
# $$

# %% [markdown]
# ## Using Matrix Formalism
#
# For a thick lens (in air):
#
# $$
# M = \begin{bmatrix}
# 1 & 0 \\
# \frac{n_l-1}{R_2} & n
# \end{bmatrix}
# \begin{bmatrix}
# 1 & t \\
# 0 & 1
# \end{bmatrix}
# \begin{bmatrix}
# 1 & 0 \\
# \frac{n_l-1}{R_1} & n
# \end{bmatrix}
# $$
#
# Now, in between the lenses we can add a translation matrix:
#
# $$
# T_{12} = \begin{bmatrix}
# 1 & d_{12} \\
# 0 & 1
# \end{bmatrix}
# $$

# %%
import numpy as np

def refraction_matrix(n, R):
    return np.array([[1,0],[(n-1)/R, n]])

def translation_matrix(d):
    return np.array([[1,d],[0,1]])

def thick_lens_matrix(n, R1, R2, t):
    refraction1 = refraction_matrix(n, R1)
    refraction2 = refraction_matrix(n, R2)
    translation = translation_matrix(t)
    return refraction2 @ translation @ refraction1

air1 = translation_matrix(100)
lens1 = thick_lens_matrix(1.5, 40, -40, 5)
air2 = translation_matrix(30)
lens2 = thick_lens_matrix(1.6, 25, -35, 4)
air3 = translation_matrix(100)

system = [air1, lens1, air2, lens2, air3]
system_xvalues = [[0, 100], [100, 105], [105, 135], [135, 139], [139, 239]] 

incoming = [ [0, 0.2], [0,-0.2], [10,0], [-10,0], [0,0] ]

coords = []

for ray in incoming:
    ray_coords = []
    for matrix in system:
        rayf = matrix @ ray
        ray_coords.append([ray, rayf])
        ray = rayf
    coords.append(ray_coords)

import matplotlib.pyplot as plt

for ray_coords in coords:
    for i in range(len(ray_coords)):
        plt.plot(system_xvalues[i], ray_coords[i])

coords
# Out:
# [[[[0, 0.2], array([20. ,  0.2])],
#   [array([20. ,  0.2]), array([22.75    ,  0.540625])],
#   [array([22.75    ,  0.540625]), array([38.96875 ,  0.540625])],
#   [array([38.96875 ,  0.540625]), array([46.16975   ,  2.08891857])],
#   [array([46.16975   ,  2.08891857]), array([255.06160714,   2.08891857])]],
#  [[[0, -0.2], array([-20. ,  -0.2])],
#   [array([-20. ,  -0.2]), array([-22.75    ,  -0.540625])],
#   [array([-22.75    ,  -0.540625]), array([-38.96875 ,  -0.540625])],
#   [array([-38.96875 ,  -0.540625]), array([-46.16975   ,  -2.08891857])],
#   [array([-46.16975   ,  -2.08891857]),
#    array([-255.06160714,   -2.08891857])]],
#  [[[10, 0], array([10,  0])],
#   [array([10,  0]), array([10.625    ,  0.0546875])],
#   [array([10.625    ,  0.0546875]), array([12.265625 ,  0.0546875])],
#   [array([12.265625 ,  0.0546875]), array([13.793125  ,  0.37454643])],
#   [array([13.793125  ,  0.37454643]), array([51.24776786,  0.37454643])]],
#  [[[-10, 0], array([-10,   0])],
#   [array([-10,   0]), array([-10.625    ,  -0.0546875])],
#   [array([-10.625    ,  -0.0546875]), array([-12.265625 ,  -0.0546875])],
#   [array([-12.265625 ,  -0.0546875]), array([-13.793125  ,  -0.37454643])],
#   [array([-13.793125  ,  -0.37454643]), array([-51.24776786,  -0.37454643])]],
#  [[[0, 0], array([0, 0])],
#   [array([0, 0]), array([0., 0.])],
#   [array([0., 0.]), array([0., 0.])],
#   [array([0., 0.]), array([0., 0.])],
#   [array([0., 0.]), array([0., 0.])]]]

# %% [markdown]
# The focal length is where an incoming parallel ray intersects the x axis.

# %%
# choose a parallel ray
ray = coords[2][-1][0]
[y, angle] = ray
print(y, angle)

f = - y * np.tan(angle)
print("Focal length:", f, "mm")
# Out:
# 13.793125000000002 0.3745464285714287
# Focal length: -5.422116344606138 mm
